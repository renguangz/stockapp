# %%
import requests
import pandas as pd
import os

# %%
url = 'https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=html&date=20200201&stockNo=2330'
data = pd.read_html(requests.get(url).text)[0]
data.columns = data.columns.droplevel(0)
# data.columns = data.columns(['Date', 'Volume', '成交金額', 'Open', 'High', 'Low', 'Close', '漲跌價差','成交筆數'])
data = data.rename(columns={'日期': 'Date', '成交股數': 'Volume', '開盤價': 'Open', '最高價': 'High', '最低價': 'Low', '收盤價': 'Close'})
path = os.path.join('./price_data', 'price_2330_20200201.csv')
print(path)
data.to_csv(path, index=False)
# Out:
# ./price_data/price_2330_20200201.csv

# %%
url = 'https://www.twse.com.tw/exchangeReport/STOCK_DAY?response=html&date=20200301&stockNo=2330'
data1 = pd.read_html(requests.get(url).text)[0]
data1.columns = data1.columns.droplevel(0)
data1 = data1.rename(columns={'日期': 'Date', '成交股數': 'Volume', '開盤價': 'Open', '最高價': 'High', '最低價': 'Low', '收盤價': 'Close'})

# %%
table = pd.read_csv('price_2330_20200201.csv', index_col='Date')
new_table = table.append(data1)
new_table.to_csv('price_2330_20200201.csv', index=False)
# Out:
# /Users/zhongrenguang/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#               Volume         成交金額   Open   High    Low  Close    漲跌價差   成交筆數
# Date
# 109/02/03   59711849  18782694826  315.0  316.5  312.0  315.0    -5.0  26483
# 109/02/04   52208496  16882411296  319.0  326.0  318.0  325.0    10.0  22587
# 109/02/05   36601453  11985817083  329.0  329.5  324.5  327.5     2.5  16656
# 109/02/06   29659094   9803038836  329.5  332.5  329.0  332.5     5.0  14246
# 109/02/07   30055327   9869903253  330.0  330.5  326.0  328.0    -4.5  13075
# 109/02/10   30814424  10024967927  321.5  328.0  321.0  327.5    -0.5  14825
# 109/02/11   29062935   9629938182  330.5  332.5  330.0  331.5     4.0  12766
# 109/02/12   37612639  12593082711  333.5  336.0  333.0  335.0     3.5  17394
# 109/02/13   23217021   7805299096  338.0  338.0  335.0  335.0     0.0  12563
# 109/02/14   18326683   6155862838  337.0  337.0  334.5  335.0     0.0   7881
# 109/02/17   16145079   5354339726  331.5  333.0  330.5  331.5    -3.5   9747
# 109/02/18   64662604  20957801150  324.5  326.5  322.0  322.0    -9.5  36520
# 109/02/19   48856218  15881609046  322.5  327.0  322.0  326.5     4.5  16003
# 109/02/20   27061736   8832642641  328.0  329.0  325.0  325.5    -1.0  11695
# 109/02/21   22974534   7463007621  325.5  326.5  323.0  325.0    -0.5   9342
# 109/02/24   42946680  13754512932  319.5  321.5  319.5  320.0    -5.0  18902
# 109/02/25   38674011  12425785349  320.0  323.5  317.5  322.0     2.0  17366
# 109/02/26   60768362  19341695595  317.0  320.5  316.5  318.5    -3.5  24310
# 109/02/27   62401927  19756146876  319.0  320.0  315.0  316.0    -2.5  20633
# 109/03/02   86372942  26864484400  308.0  317.0  308.0  311.0   -5.00  35320
# 109/03/03   55169411  17534766696  318.5  320.0  316.0  317.5   +6.50  20713
# 109/03/04   44745146  14304795666  322.0  322.0  317.0  320.5   +3.00  16118
# 109/03/05   38223525  12392618100  325.0  326.0  323.0  323.0   +2.50  15107
://www.twse.com.tw/exchangeReport/STOCK_DAY?response=html&date=' + str(date) + '&stockNo=' + str(stockid)
    data = pd.read_html(requests.get(url).text)[0]
    data.columns = data.columns.droplevel(0)
    data = data.rename(columns={'日期': 'date', '成交股數': 'volume', '開盤價': 'open', '最高價': 'high', '最低價': 'low', '收盤價': 'close'})
    data['volume'] = data['volume'] / 1000
    path = os.path.join('./price_data', 'price_' + str(stockid) + '.csv') # 路徑要換成下面的
    # 還沒有建立個股的csv時，使用下面的
#     data.to_csv(path, index=True)
    conn = sqlite3.connect('price.db')
    sql_table = pd.read_sql('select * from price_' + str(stockid), conn)
    sql_table = sql_table.append(data)
    sql_table = sql_table.set_index('date')
    sql_table = sql_table[sql_table.index.duplicated() == False]
    ma5 = sql_table['close'].rolling(5).mean()
    ma10 = sql_table['close'].rolling(10).mean()
    ma20 = sql_table['close'].rolling(20).mean()
    volumeMa5 = sql_table['volume'].rolling(5).mean()
    volumeMa10 = sql_table['volume'].rolling(10).mean()
    volumeMa20 = sql_table['volume'].rolling(20).mean()
    kd = abstract.STOCH(sql_table)
    slowj = kd['slowk'] * 3 - kd['slowd'] * 2
    sql_table = sql_table.assign(ma5=ma5, ma10=ma10, ma20=ma20, volumeMa5=volumeMa5, volumeMa10=volumeMa10, volumeMa20=volumeMa20, slowk=kd['slowk'], slowd=kd['slowd'], slowj=slowj)
    sql_table.to_sql('price_' + str(stockid), conn, if_exists='replace')
    
#     table = pd.read_csv(path)
#     new_table = table.append(data)
#     new_table = new_table.set_index('date')
#     new_table = new_table[new_table.index.duplicated() == False]
#     ma5 = new_table['close'].rolling(5).mean()
#     ma10 = new_table['close'].rolling(10).mean()
#     ma20 = new_table['close'].rolling(20).mean()
#     new_table = new_table.assign(ma5=ma5, ma10=ma10, ma20=ma20)
#     new_table.to_csv(path, index=True)
#     time.sleep(2)
    return sql_table
    # 先把每個股票資料都存成個別csv
    # 在進行read_csv，爬下一個月份資料，把資料放進read_csv的table裡面，再存回csv

# %%
download_table = [1101, 2317, 2330, 2498]
for d in download_table:
    table = crawl_price(d, '20210901')
table
# Out:
# /Users/zhongrenguang/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:6692: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort)
#            close   high  index    low    ma10     ma20    ma5   open  \
# date
# 110/04/01  31.20  31.50    0.0  30.80     NaN      NaN    NaN  31.25
# 110/04/06  30.95  31.65    1.0  30.90     NaN      NaN    NaN  31.60
# 110/04/07  31.45  32.45    2.0  31.25     NaN      NaN    NaN  31.25
# 110/04/08  31.45  31.80    3.0  31.20     NaN      NaN    NaN  31.55
# 110/04/09  31.50  31.80    4.0  31.20     NaN      NaN  31.31  31.80
# 110/04/12  32.80  33.00    5.0  31.50     NaN      NaN  31.63  31.65
# 110/04/13  33.10  33.90    6.0  32.90     NaN      NaN  32.06  33.00
# 110/09/07   3958.22430   2779.7422   2229   137887024 -0.60
# 110/09/08   3751.21960   3013.4228   1926   109790065 -0.30
# 110/09/09   3644.75720   2631.5154   1022    52820845  0.20
# 110/09/10   3445.38250   2533.2548    944    53079041  0.25
# 110/09/13   3889.20690   4957.2308   7126   537938798  3.00
#
# [114 rows x 18 columns]

# %% [markdown]
# ## twstock

# %%
import twstock
from twstock import codes
import sqlite3
import pandas as pd
import json
from ast import literal_eval

# %%
# twstock.realtime.mock = False
# arr = ['1101', '2330', '2317', '2498']
# data = twstock.realtime.get(arr)      
# data

# 一次抓取所有台股資料
arr_all = []
conn_all_stock = sqlite3.connect('stockInfo.db')
all_stock_table = pd.read_sql('select 有價證券代號及名稱 from stock_name', conn_all_stock)
all_stock_table = all_stock_table.iloc[:953]
all_stock_table
# Out:
#         有價證券代號及名稱
# 0              股票
# 1         1101　台泥
# 2         1102　亞泥
# 3         1103　嘉泥
# 4         1104　環泥
# 5         1108　幸福
# 6         1109　信大
# 7         1110　東泥
# 8         1201　味全
# 9         1203　味王
# 10        1210　大成
# 11        1213　大飲
# 12        1215　卜蜂
# 13        1216　統一
# 14       1217　愛之味
# 15        1218　泰山
# 16        1219　福壽
# 17        1220　台榮
# 18       1225　福懋油
# 19        1227　佳格
# 20        1229　聯華
# 21       1231　聯華食
# 22       1232　大統益
# 23        1233　天仁
# 24        1234　黑松
# 25        1235　興泰
# 26        1236　宏亞
# 27   1256　鮮活果汁-KY
# 28        1301　台塑
# 29        1303　南亞
# ..            ...
# 923       9911　櫻花
# 924       9912　偉聯
# 925      9914　美利達
# 926      9917　中保科
# 927      9918　欣天然
# 928      9919　康那香
# 929       9921　巨大
# 930       9924　福興
# 931       9925　新保
# 932       9926　新海
# 933       9927　泰銘
# 934       9928　中視
# 935       9929　秋雨
# 936     9930　中聯資源
# 937       9931　欣高
# 938       9933　中鼎
# 939       9934　成霖
# 940      9935　慶豐富
# 941       9937　全國
# 942       9938　百和
# 943       9939　宏全
# 944       9940　信義
# 945       9941　裕融
# 946       9942　茂順
# 947      9943　好樂迪
# 948       9944　新麗
# 949      9945　潤泰新
# 950     9946　三發地產
# 951       9955　佳龍
# 952      9958　世紀鋼
#
# [953 rows x 1 columns]

# %%
arr_list = all_stock_table['有價證券代號及名稱'].tolist()
del(arr_list[0])
del(arr_list[651])

# %%
for i in arr_list:
    stockid = i.split('\u3000')[0]
    arr_all.append(stockid)

# %%
arr_all
# Out:
# ['1101',
#  '1102',
#  '1103',
#  '1104',
#  '1108',
#  '1109',
#  '1110',
#  '1201',
#  '1203',
#  '1210',
#  '1213',
#  '1215',
#  '1216',
#  '1217',
#  '1218',
#  '1219',
#  '1220',
#  '1225',
#  '1227',
#  '1229',
#  '1231',
#  '1232',
#  '1233',
#  '1234',
#  '1235',
#  '1236',
#  '1256',
#  '1301',
#  '1303',
#  '1304',
#  '1305',
#  '1307',
#  '1308',
#  '1309',
#  '1310',
#  '1312',
#  '1313',
#  '1314',
#  '1315',
#  '1316',
#  '1319',
#  '1321',
#  '1323',
#  '1324',
#  '1325',
#  '1326',
#  '1337',
#  '1338',
#  '1339',
#  '1340',
#  '1341',
#  '1342',
#  '1402',
#  '1409',
#  '1410',
#  '1413',
#  '1414',
#  '1416',
#  '1417',
#  '1418',
#  '1419',
#  '1423',
#  '1432',
#  '1434',
#  '1435',
#  '1436',
#  '1437',
#  '1438',
#  '1439',
#  '1440',
#  '1441',
#  '1442',
#  '1443',
#  '1444',
#  '1445',
#  '1446',
#  '1447',
#  '1449',
#  '1451',
#  '1452',
#  '1453',
#  '1454',
#  '1455',
#  '1456',
#  '1457',
#  '1459',
#  '1460',
#  '1463',
#  '1464',
#  '1465',
#  '1466',
#  '1467',
#  '1468',
#  '1470',
#  '1471',
#  '1472',
#  '1473',
#  '1474',
#  '1475',
#  '1476',
#  '1477',
#  '1503',
#  '1504',
#  '1506',
#  '1507',
#  '1512',
#  '1513',
#  '1514',
#  '1515',
#  '1516',
#  '1517',
#  '1519',
#  '1521',
#  '1522',
#  '1524',
#  '1525',
#  '1526',
#  '1527',
#  '1528',
#  '1529',
#  '1530',
#  '1531',
#  '1532',
#  '1533',
#  '1535',
#  '1536',
#  '1537',
#  '1538',
#  '1539',
#  '1540',
#  '1541',
#  '1558',
#  '1560',
#  '1568',
#  '1582',
#  '1583',
#  '1587',
#  '1589',
#  '1590',
#  '1592',
#  '1597',
#  '1598',
#  '1603',
#  '1604',
#  '1605',
#  '1608',
#  '1609',
#  '1611',
#  '1612',
#  '1614',
#  '1615',
#  '1616',
#  '1617',
#  '1618',
#  '1626',
#  '1701',
#  '1702',
#  '1707',
#  '1708',
#  '1709',
#  '1710',
#  '1711',
#  '1712',
#  '1713',
#  '1714',
#  '1717',
#  '1718',
#  '1720',
#  '1721',
#  '1722',
#  '1723',
#  '1724',
#  '1725',
#  '1726',
#  '1727',
#  '1730',
#  '1731',
#  '1732',
#  '1733',
#  '1734',
#  '1735',
#  '1736',
#  '1737',
#  '1760',
#  '1762',
#  '1773',
#  '1776',
#  '1783',
#  '1786',
#  '1789',
#  '1795',
#  '1802',
#  '1805',
#  '1806',
#  '1808',
#  '1809',
#  '1810',
#  '1817',
#  '1903',
#  '1904',
#  '1905',
#  '1906',
#  '1907',
#  '1909',
#  '2002',
#  '2006',
#  '2007',
#  '2008',
#  '2009',
#  '2010',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2017',
#  '2020',
#  '2022',
#  '2023',
#  '2024',
#  '2025',
#  '2027',
#  '2028',
#  '2029',
#  '2030',
#  '2031',
#  '2032',
#  '2033',
#  '2034',
#  '2038',
#  '2049',
#  '2059',
#  '2062',
#  '2069',
#  '2101',
#  '2102',
#  '2103',
#  '2104',
#  '2105',
#  '2106',
#  '2107',
#  '2108',
#  '2109',
#  '2114',
#  '2115',
#  '2201',
#  '2204',
#  '2206',
#  '2207',
#  '2208',
#  '2211',
#  '2227',
#  '2228',
#  '2231',
#  '2233',
#  '2236',
#  '2239',
#  '2241',
#  '2243',
#  '2247',
#  '2301',
#  '2302',
#  '2303',
#  '2305',
#  '2308',
#  '2312',
#  '2313',
#  '2314',
#  '2316',
#  '2317',
#  '2321',
#  '2323',
#  '2324',
#  '2327',
#  '2328',
#  '2329',
#  '2330',
#  '2331',
#  '2332',
#  '2337',
#  '2338',
#  '2340',
#  '2342',
#  '2344',
#  '2345',
#  '2347',
#  '2348',
#  '2349',
#  '2351',
#  '2352',
#  '2353',
#  '2354',
#  '2355',
#  '2356',
#  '2357',
#  '2358',
#  '2359',
#  '2360',
#  '2362',
#  '2363',
#  '2364',
#  '2365',
#  '2367',
#  '2368',
#  '2369',
#  '2371',
#  '2373',
#  '2374',
#  '2375',
#  '2376',
#  '2377',
#  '2379',
#  '2380',
#  '2382',
#  '2383',
#  '2385',
#  '2387',
#  '2388',
#  '2390',
#  '2392',
#  '2393',
#  '2395',
#  '2397',
#  '2399',
#  '2401',
#  '2402',
#  '2404',
#  '2405',
#  '2406',
#  '2408',
#  '2409',
#  '2412',
#  '2413',
#  '2414',
#  '2415',
#  '2417',
#  '2419',
#  '2420',
#  '2421',
#  '2423',
#  '2424',
#  '2425',
#  '2426',
#  '2427',
#  '2428',
#  '2429',
#  '2430',
#  '2431',
#  '2433',
#  '2434',
#  '2436',
#  '2438',
#  '2439',
#  '2440',
#  '2441',
#  '2442',
#  '2443',
#  '2444',
#  '2449',
#  '2450',
#  '2451',
#  '2453',
#  '2454',
#  '2455',
#  '2456',
#  '2457',
#  '2458',
#  '2459',
#  '2460',
#  '2461',
#  '2462',
#  '2464',
#  '2465',
#  '2466',
#  '2467',
#  '2468',
#  '2471',
#  '2472',
#  '2474',
#  '2476',
#  '2477',
#  '2478',
#  '2480',
#  '2481',
#  '2482',
#  '2483',
#  '2484',
#  '2485',
#  '2486',
#  '2488',
#  '2489',
#  '2491',
#  '2492',
#  '2493',
#  '2495',
#  '2496',
#  '2497',
#  '2498',
#  '2501',
#  '2504',
#  '2505',
#  '2506',
#  '2509',
#  '2511',
#  '2514',
#  '2515',
#  '2516',
#  '2520',
#  '2524',
#  '2527',
#  '2528',
#  '2530',
#  '2534',
#  '2535',
#  '2536',
#  '2537',
#  '2538',
#  '2539',
#  '2540',
#  '2542',
#  '2543',
#  '2545',
#  '2546',
#  '2547',
#  '2548',
#  '2597',
#  '2601',
#  '2603',
#  '2605',
#  '2606',
#  '2607',
#  '2608',
#  '2609',
#  '2610',
#  '2611',
#  '2612',
#  '2613',
#  '2614',
#  '2615',
#  '2616',
#  '2617',
#  '2618',
#  '2630',
#  '2633',
#  '2634',
#  '2636',
#  '2637',
#  '2642',
#  '2701',
#  '2702',
#  '2704',
#  '2705',
#  '2706',
#  '2707',
#  '2712',
#  '2722',
#  '2723',
#  '2727',
#  '2731',
#  '2739',
#  '2748',
#  '2801',
#  '2809',
#  '2812',
#  '2816',
#  '2820',
#  '2823',
#  '2832',
#  '2834',
#  '2836',
#  '2838',
#  '2841',
#  '2845',
#  '2849',
#  '2850',
#  '2851',
#  '2852',
#  '2855',
#  '2867',
#  '2880',
#  '2881',
#  '2882',
#  '2883',
#  '2884',
#  '2885',
#  '2886',
#  '2887',
#  '2888',
#  '2889',
#  '2890',
#  '2891',
#  '2892',
#  '2897',
#  '2901',
#  '2903',
#  '2904',
#  '9918',
#  '9919',
#  '9921',
#  '9924',
#  '9925',
#  '9926',
#  '9927',
#  '9928',
#  '9929',
#  '9930',
#  '9931',
#  '9933',
#  '9934',
#  '9935',
#  '9937',
#  '9938',
#  '9939',
#  '9940',
#  '9941',
#  '9942',
#  '9943',
#  '9944',
#  '9945',
#  '9946',
#  '9955',
#  '9958']

# %%
len(arr_all)
# Out:
# 951

# %%
data = twstock.realtime.get(arr_all[:300])      
data
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 51] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     354         else:
# --> 355             conn.request(method, url, **httplib_request_kw)
#     356
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1251         """Send a complete request to the server."""
# -> 1252         self._send_request(method, url, body, headers, encode_chunked)
#    1253
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1297             body = _encode(body, 'body')
# -> 1298         self.endheaders(body, encode_chunked=encode_chunked)
#    1299
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1246             raise CannotSendHeader()
# -> 1247         self._send_output(message_body, encode_chunked=encode_chunked)
#    1248
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1025         del self._buffer[:]
# -> 1026         self.send(msg)
#    1027
#
# ~/opt/anaconda3/lib/python3.7/http/client.py in send(self, data)
#     965             if self.auto_open:
# --> 966                 self.connect()
#     967             else:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     182     def connect(self):
# --> 183         conn = self._new_conn()
#     184         self._prepare_conn(conn)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e)
#     170
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7fa2c6faa510>: Failed to establish a new connection: [Errno 51] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPConnectionPool(host='mis.twse.com.tw', port=80): Max retries exceeded with url: /stock/index.jsp (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa2c6faa510>: Failed to establish a new connection: [Errno 51] Network is unreachable'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-205-6903eebe2a23> in <module>
# ----> 1 data = twstock.realtime.get(arr_all[:300])
#       2 data
#
# ~/opt/anaconda3/lib/python3.7/site-packages/twstock/realtime.py in get(stocks, retry)
#      90 def get(stocks, retry=3):
#      91     # Prepare data
# ---> 92     data = get_raw(stocks) if not mock else twstock.mock.get(stocks)
#      93
#      94     # Set success
#
# ~/opt/anaconda3/lib/python3.7/site-packages/twstock/realtime.py in get_raw(stocks)
#      69 def get_raw(stocks) -> dict:
#      70     req = requests.Session()
# ---> 71     req.get(SESSION_URL, proxies=get_proxies())
#      72
#      73     r = req.get(
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='mis.twse.com.tw', port=80): Max retries exceeded with url: /stock/index.jsp (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7fa2c6faa510>: Failed to establish a new connection: [Errno 51] Network is unreachable'))

# %%
table = data['1101']['realtime']
table
# Out:
# {'latest_trade_price': '51.4000',
#  'trade_volume': '2036',
#  'accumulate_trade_volume': '52168',
#  'best_bid_price': ['51.4000', '51.3000', '51.2000', '51.1000', '51.0000'],
#  'best_bid_volume': ['244', '336', '353', '575', '769'],
#  'best_ask_price': ['51.5000', '51.6000', '51.7000', '51.8000', '51.9000'],
#  'best_ask_volume': ['1539', '640', '874', '1348', '1119'],
#  'open': '51.1000',
#  'high': '52.0000',
#  'low': '50.7000'}

# %%
conn = sqlite3.connect('twstock.db')
df = pd.DataFrame(list(table.items())).T
df.columns = df.iloc[0]
df = df.drop(0)
df
# table.keys()
# Out:
# 0 latest_trade_price trade_volume accumulate_trade_volume  \
# 1            51.4000         2036                   52168
#
# 0                                 best_bid_price            best_bid_volume  \
# 1  [51.4000, 51.3000, 51.2000, 51.1000, 51.0000]  [244, 336, 353, 575, 769]
#
# 0                                 best_ask_price  \
# 1  [51.5000, 51.6000, 51.7000, 51.8000, 51.9000]
#
# 0               best_ask_volume     open     high      low
# 1  [1539, 640, 874, 1348, 1119]  51.1000  52.0000  50.7000
