# %%
import requests
from io import StringIO
import pandas as pd
import sqlite3
import time

# %% [markdown]
# ## 上市公司資訊爬蟲

# %%
res = requests.get("http://isin.twse.com.tw/isin/C_public.jsp?strMode=2")
df = pd.read_html(res.text)[0]

df.columns = df.iloc[0]
df = df.iloc[1:]
df = df.dropna(thresh=3, axis=0).dropna(thresh=3, axis=1)
# df = df.set_index('有價證券代號及名稱')
conn = sqlite3.connect('stockInfo.db')
# df.to_sql('stock_name', conn, if_exists='replace')
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-c9ccac05fe83> in <module>
# ----> 1 res = requests.get("http://isin.twse.com.tw/isin/C_public.jsp?strMode=2")
#       2 df = pd.read_html(res.text)[0]
#       3
#       4 df.columns = df.iloc[0]
#       5 df = df.iloc[1:]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/opt/anaconda3/lib/python3.7/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ...

# %%
df.iloc[0]

# %%
dfs = []
url = 'https://mops.twse.com.tw/mops/web/ajax_t164sb03'
stock_id = 1101
year = range(107, 109)
season = range(1, 5)
for y in year:
    for s in season:
        form_data = {
            'encodeURIComponent': '',
            'step': '1',
            'firstin': '1',
            'off': '1',
            'queryName': 'co_id',
            'inpuType': 'co_id',
            'TYPEK': 'all',
            'isnew': 'false',
            'co_id': str(stock_id),
            'year': str(y),
            'season': str(s),
        }

        res = requests.post(url, data=form_data)
        table = pd.read_html(res.text)[1]
        table = table.iloc[:, 0:2]
        table.columns = table.columns.get_level_values(2)
        dfs.append(table)
        time.sleep(3)
table
# Out:
#                          會計項目   108年12月31日
# 0                        流動資產          NaN
# 1                     現金及約當現金   53572620.0
# 2         透過損益按公允價值衡量之金融資產－流動     502005.0
# 3     透過其他綜合損益按公允價值衡量之金融資產－流動    7180745.0
# 4            按攤銷後成本衡量之金融資產－流動    4745911.0
# ..                        ...          ...
# 56                      非控制權益   14777799.0
# 57                       權益總額  208461867.0
# 58                    負債及權益總計  367482385.0
# 59    預收股款（權益項下）之約當發行股數（單位：股）          0.0
# 60  母公司暨子公司所持有之母公司庫藏股股數（單位：股）    8000000.0
#
# [61 rows x 2 columns]

# %%
# income statement
url = 'https://mops.twse.com.tw/mops/web/ajax_t164sb04'
stock_id = 1101
y = 102
s = 3
year = range(102, 104)
season = range(1, 5)
# for y in year:
#     for s in season:
form_data = {
    'encodeURIComponent': '',
    'step': '1',
    'firstin': '1',
    'off': '1',
    'queryName': 'co_id',
    'inpuType': 'co_id',
    'TYPEK': 'all',
    'isnew': 'false',
    'co_id': str(stock_id),
    'year': str(y),
    'season': str(s),
}

res = requests.post(url, data=form_data)
table = pd.read_html(res.text)[1]
time.sleep(3)
table = table.iloc[:, 0:2]
table.columns = table.columns.get_level_values(2)
table
# Out:
#                            會計項目  102年07月01日至102年09月30日
# 0                        銷貨收入淨額            30106839.00
# 1                        營業收入合計            30106839.00
# 2                        其他營業成本            23052350.00
# 3                        營業成本合計            23052350.00
# 4                      營業毛利（毛損）             7054489.00
# 5                    營業毛利（毛損）淨額             7054489.00
# 6                          營業費用                    NaN
# 7                          推銷費用              248458.00
# 8                          管理費用              884978.00
# 9                        研究發展費用               10419.00
# 10                       營業費用合計             1143855.00
# 11                     營業利益（損失）             5910634.00
# 12                     營業外收入及支出                    NaN
# 13                         其他收入              842310.00
# 14                    其他利益及損失淨額                   0.00
# 15                       財務成本淨額              526755.00
# ...

# %%
def get_balance_sheet(stock_id, start_year, end_year):
    balance_sheet_url = 'https://mops.twse.com.tw/mops/web/ajax_t164sb03'
    income_statement_url = 'https://mops.twse.com.tw/mops/web/ajax_t164sb04'
    cash_flows_url = 'https://mops.twse.com.tw/mops/web/ajax_t164sb05'
    
    url = income_statement_url
    
    year = range(start_year, end_year+1)
    season = range(1, 5)
    dfs = []
    for y in year:
        for s in season:
            form_data = {
                'encodeURIComponent': '',
                'step': '1',
                'firstin': '1',
                'off': '1',
                'queryName': 'co_id',
                'inpuType': 'co_id',
                'TYPEK': 'all',
                'isnew': 'false',
                'co_id': str(stock_id),
                'year': str(y),
                'season': str(s),
            }

            res = requests.post(url, data=form_data)
            table = pd.read_html(res.text)[1]
            table = table.iloc[:, 0:2]
            table.columns = table.columns.get_level_values(2)
            dfs.append(table)
            time.sleep(3)
            
    df_final = pd.DataFrame(columns=['會計項目'])
    for df in dfs:
        df_final = df_final.merge(df, on='會計項目', how='outer')
    df_final = df_final.set_index('會計項目')
    df_final = df_final.T.reset_index()
    df_final = df_final.rename(columns={'index': 'date'})
    conn = sqlite3.connect('income_statement.db')

    df_final.to_sql('_' + str(stock_id), conn, if_exists='replace')
    return df_final

# %%
table_2317 = get_balance_sheet(2317, 102, 103)
table_2317
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3adf8934aaba> in <module>
# ----> 1 table_2317 = get_balance_sheet(2317, 102, 103)
#       2 table_2317
#
# <ipython-input-1-991b88e60d0d> in get_balance_sheet(stock_id, start_year, end_year)
#      25             }
#      26
# ---> 27             res = requests.post(url, data=form_data)
#      28             table = pd.read_html(res.text)[1]
#      29             table = table.iloc[:, 0:2]
#
# NameError: name 'requests' is not defined

# %%
table_2330 = get_finance(2330, 102, 103)
table_1101 = get_finance(1101, 102, 103)
table_1102 = get_finance(1102, 102, 103)
table_3481 = get_finance(3481, 102, 103)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-90-b736ce7c901c> in <module>
# ----> 1 table_2330 = get_finance(2330, 102, 103, 'cash_flow')
#       2 table_1101 = get_finance(1101, 102, 103, 'cash_flow')
#       3 table_1102 = get_finance(1102, 102, 103, 'cash_flow')
#       4 table_3481 = get_finance(3481, 102, 103, 'cash_flow')
#
# <ipython-input-88-3920fb2996a2> in get_finance(stock_id, start_year, end_year, db_name)
#      41     conn = sqlite3.connect(str(db_name) + '.db')
#      42
# ---> 43     df_final.to_sql('_' + str(stock_id), conn, if_exists='replace')
#      44     return df_final
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# ...

# %%
table_3481.columns
# Out:
# Index(['date', '流動資產', '現金及約當現金', '透過損益按公允價值衡量之金融資產－流動', '備供出售金融資產－流動淨額',
#        '應收帳款淨額', '應收帳款－關係人淨額', '其他應收款淨額', '存貨', '預付款項', '待出售非流動資產（淨額）',
#        '其他流動資產', '流動資產合計', '非流動資產', '透過損益按公允價值衡量之金融資產－非流動', '備供出售金融資產－非流動淨額',
#        '以成本衡量之金融資產－非流動淨額', '採用權益法之投資淨額', '不動產、廠房及設備', '投資性不動產淨額', '無形資產',
#        '遞延所得稅資產', '其他非流動資產', '非流動資產合計', '資產總額', '流動負債', '短期借款', '應付短期票券',
#        '透過損益按公允價值衡量之金融負債－流動', '避險之衍生金融負債－流動', '應付帳款', '應付帳款－關係人', '其他應付款',
#        '當期所得稅負債', '負債準備－流動', '其他流動負債', '流動負債合計', '非流動負債',
#        '透過損益按公允價值衡量之金融負債－非流動', '避險之衍生金融負債－非流動', '應付公司債', '長期借款', '遞延所得稅負債',
#        '其他非流動負債', '非流動負債合計', '負債總額', '歸屬於母公司業主之權益', '股本', '普通股股本', '股本合計',
#        '資本公積', '資本公積－發行溢價', '資本公積－採用權益法認列關聯企業及合資股權淨值之變動數', '資本公積－員工認股權',
#        '資本公積－其他', '資本公積合計', '保留盈餘', '法定盈餘公積', '未分配盈餘（或待彌補虧損）', '保留盈餘合計',
#        '其他權益', '國外營運機構財務報表換算之兌換差額', '備供出售金融資產未實現損益',
#        '現金流量避險中屬有效避險部分之避險工具利益（損失）', '其他權益－其他', '其他權益合計', '庫藏股票',
# ...

# %% [markdown]
# ## dataframe 設置 primay key

# %%
conn = sqlite3.connect('balance_sheet.db')
table = pd.read_sql('select * from _3481', conn, index_col=None)
table_new = table.rename(columns={'index': 'id'})
table_new = table_new.set_index('id')

table_new.to_sql('_3481_2', conn, if_exists='replace')

table_new
# Out:
#           date  流動資產     現金及約當現金  透過損益按公允價值衡量之金融資產－流動  備供出售金融資產－流動淨額  \
# id
# 0   102年03月31日  None  42652394.0             627959.0        93481.0
# 1   102年06月30日  None  37882475.0             321555.0            0.0
# 2   102年09月30日  None  40920556.0             225066.0            0.0
# 3   102年12月31日  None  44137818.0             227703.0            0.0
# 4   103年03月31日  None  36244705.0              90518.0            0.0
# 5   103年06月30日  None  24903724.0              88742.0            0.0
# 6   103年09月30日  None  34575186.0              59014.0            0.0
# 7   103年12月31日  None  70989741.0              52453.0       220000.0
#
#         應收帳款淨額  應收帳款－關係人淨額    其他應收款淨額          存貨       預付款項  ...  庫藏股票  \
# id                                                            ...
# 0   78597752.0   2832300.0  1967210.0  45183183.0  1047805.0  ...   0.0
# 1   68843875.0   2157345.0  2448112.0  44549676.0  1430842.0  ...   NaN
# ...
