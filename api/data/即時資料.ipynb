# %%
import twstock
import pandas as pd

# %%
stock_2330 = twstock.realtime.get('2330')
result = pd.DataFrame(stock_2330).T.iloc[1:3]
result
# Out:
#          accumulate_trade_volume  \
# info                         NaN
# realtime                   16646
#
#                                              best_ask_price  \
# info                                                    NaN
# realtime  [598.0000, 599.0000, 600.0000, 601.0000, 602.0...
#
#                     best_ask_volume  \
# info                            NaN
# realtime  [2, 1123, 1504, 589, 487]
#
#                                              best_bid_price  \
# info                                                    NaN
# realtime  [597.0000, 596.0000, 595.0000, 594.0000, 593.0...
#
#                  best_bid_volume  channel  code        fullname      high  \
# info                         NaN  2330.tw  2330  台灣積體電路製造股份有限公司       NaN
# realtime  [41, 68, 91, 343, 916]      NaN   NaN             NaN  598.0000
#
#          latest_trade_price       low name      open                 time  \
# info                    NaN       NaN  台積電       NaN  2021-09-24 14:25:00
# realtime           598.0000  590.0000  NaN  591.0000                  NaN
#
#          trade_volume
# info              NaN
# realtime         3522

# %%
result.columns= ['成交量', '買進五檔', '買進五檔單量', '賣出五檔', '賣出五檔單量', 'channel', 'code', 'fullname', 'high', 'close', 'low', 'name', 'open', 'time', 'trade_volume']
result
# Out:
#             成交量                                               買進五檔  \
# info        NaN                                                NaN
# realtime  16646  [598.0000, 599.0000, 600.0000, 601.0000, 602.0...
#
#                              買進五檔單量  \
# info                            NaN
# realtime  [2, 1123, 1504, 589, 487]
#
#                                                        賣出五檔  \
# info                                                    NaN
# realtime  [597.0000, 596.0000, 595.0000, 594.0000, 593.0...
#
#                           賣出五檔單量  channel  code        fullname      high  \
# info                         NaN  2330.tw  2330  台灣積體電路製造股份有限公司       NaN
# realtime  [41, 68, 91, 343, 916]      NaN   NaN             NaN  598.0000
#
#              close       low name      open                 time trade_volume
# info           NaN       NaN  台積電       NaN  2021-09-24 14:25:00          NaN
# realtime  598.0000  590.0000  NaN  591.0000                  NaN         3522
